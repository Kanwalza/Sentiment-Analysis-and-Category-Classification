# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
from sklearn import naive_bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import spacy
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
import unicodedata
from sklearn.metrics import roc_auc_score, roc_curve, auc, accuracy_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import SGDClassifier, LogisticRegression
from nltk.corpus import stopwords
import sys
import sklearn
pd.set_option('display.max_rows', None)
df = pd.read_csv('neg.csv', header= 0,
                        encoding= 'unicode_escape')
print (df.head(10))
# Out:
#    App_name   Category                                        User_Review  \
# 0  duolingo  Education                                    App is crashing
# 1  duolingo  Education                   app slow and can't be turned off
# 2  duolingo  Education                        the app has so much problem
# 3  duolingo  Education  I would give more for the app itself, but this...
# 4  duolingo  Education  they have became too greedy. They are making t...
# 5  duolingo  Education  app doesn't care about you unless you pay its ...
# 6  duolingo  Education  It's a fine app but the constant pushing for a...
# 7  duolingo  Education                            app takes so much space
# 8  duolingo  Education  The last android update it just crashes and ta...
# 9  duolingo  Education         all features are not unlock due to payment
#
#   Sentiments Review_Type
# 0   Negative    AppCrash
# 1   Negative    AppCrash
# 2   Negative    AppCrash
# 3   Negative    AppCrash
# 4   Negative          PI
# 5   Negative    AppCrash
# 6   Negative    AppCrash
# 7   Negative          PI
# 8   Negative    AppCrash
# 9   Negative          FI

# %%
classes = df['Sentiments']
print(classes.value_counts())
# Out:
# Negative    483
# Name: Sentiments, dtype: int64

# %%
classess = df['Review_Type']
print(classess.value_counts())
# Out:
# AppCrash    151
# CI           90
# FI           66
# PI           48
# FR           32
# AI           32
# VU           28
# BR           21
# UI           15
# Name: Review_Type, dtype: int64

# %%
df.head()
# Out:
#    App_name   Category                                        User_Review  \
# 0  duolingo  Education                                    App is crashing
# 1  duolingo  Education                   app slow and can't be turned off
# 2  duolingo  Education                        the app has so much problem
# 3  duolingo  Education  I would give more for the app itself, but this...
# 4  duolingo  Education  they have became too greedy. They are making t...
#
#   Sentiments Review_Type
# 0   Negative    AppCrash
# 1   Negative    AppCrash
# 2   Negative    AppCrash
# 3   Negative    AppCrash
# 4   Negative          PI

# %%
summary = df['User_Review']
#print(Review[:10])
processed = summary.str.replace(r'^\$?([1-9]{1}[0-9]{0,2}(\,[0-9]{3})*(\.[0-9]{0,2})?|[1-9]{1}[0-9]{0,}(\.[0-9]{0,2})?|0(\.[0-9]{0,2})?|(\.[0-9]{1,2})?)$' , 'moneysymbol')
processed = processed.str.replace(r'(\d)' , '')
processed = processed.str.replace(r'^\D?(\d{3})\D?\D?(\d{3})\D?(\d{4})$' , ' ')
processed = processed.str.replace(r'\s+' , ' ')
processed = processed.str.replace(r'[ \t]+$' , ' ')
processed = processed.str.replace(r'[&#();*]' , ' ')
processed = processed.str.replace(r'[,:]' , ' ')
processed = processed.str.replace(r'[.!?\\-]' , ' ')
processed = processed.str.replace(r'\'' , ' ')
processed = processed.str.lower()
processed = processed.str.replace(r'\s[a-z]\s' , ' ')
processed = processed.str.replace(r'\[[^\]]*\]',' ')
processed = processed.str.replace(r'\"',' ')
processed = processed.str.replace(r'\`',' ')
print(processed)
# Out:
# 0                                        app is crashing
# 1                         app slow and can be turned off
# 2                            the app has so much problem
# 3      i would give more for the app itself  but this...
# 4      they have became too greedy  they are making t...
# 5      app doesn care about you unless you pay its st...
# 6      it a fine app but the constant pushing for app...
# 7                                app takes so much space
# 8      the last android update it just crashes and ta...
# 9             all features are not unlock due to payment
# 10     before  app was fine  but now you won be learn...
# 11     this app is good but at challenges of any leve...
# 12     swoosh after about month of use yesterday the ...
# 13     without purchasing its crashing again and agai...
# 14                                  app is not supported
# 15     i am not happy to tolerate the repeated advert...
# 16                                           app is fail
# 17     used to be great app  but recently it became a...
# 18                                  so many ad are shown
# 19           so much ads are shown still in paid account
# 20                       so many ads on the free version
# 21      the app was good  but now there is too many ads
# 22     too much fluff  animations and commercials bet...
# 23     i like the app but now that there are so many ...
# 24      they ruined the app after updation shows many...
# 25     now it bloated with ads  to the point that you...
# 26                                            lot of ads
# 27                  super loud video and irritating ads
# 28     what the hell is going on with the hearts and ...
# 29     this app dunno why need hearts and bunch of ads
# 30           i still like it but am fed up with all ads
# 31         you really need to address advertisment issue
# 32     trying to enjoy the app but cant because of ad...
# 33     annoying how pushy they are about the paid ver...
# 34                               so much ads in this app
# 35     i wish it would let me watch ads for more answers
# 36                                               stop ai
# 37     i dont like this app so many adds are contino...
# 38                                so many adds are shown
# 39                                         misleading ai
# 40                            ais are so much irritating
# 41     i purchased for removing ads  next time if rem...
# 42                                          bad ai issue
# 43                                 the worst part is ais
# 44                               they have too many adds
# 45                                     too bad the adds
# 46                                    so many ads in app
# 47     app is not running perfectly after updation ap...
# 48                                  it doesnot work well
# 49                     i like it but it stuck in between
# 50              not working properly plz fix the problem
# 51                     app is not good  stuck in between
# 52                                  not working properly
# 53                                    app is not working
# 54               this app will be not started some issue
# 55                                        so many issues
# 56                                      app is troubling
# 57                                          its annoying
# 58                                  not working properly
# 59                      it shows brainly not responding
# 60              not working in all platform sychronously
# 61                                       app is not good
# 62      it saying no connection  pls fix this need th...
# 63                                    app is frustrating
# 64     it is gettingworse day by day   cannot directl...
# 65                 something went wrong please try again
# 66     this helps me alot  but why can not use it now...
# 67     include some more excited features  not intere...
# 68     press scan and solve its crashing sometimes an...
# 69       the problem have to fix  not perform accurately
# 70                                    app is not working
# 71                               some times it has error
# 72                          i had little trouble with it
# 73                                 i cant see the answer
# 74     it will be help at times but for other times  ...
# 75                    i donot like this app not working
# 76     work fine on my google   but crash every time ...
# 77                   am not able to login using browser
# 78     is there any problem going on with the app  am...
# 79      please fix download want to be able to download
# 80          app and website is not running synchronously
# 81              after update app is not working properly
# 82            i have to force close the app and restart
# 83             app does not syncs properly with the web
# 84     internet connection is very poor  every time e...
# 85                                 so many errors in app
# 86     even after proper internet connection it does ...
# 87                        endless crashes  fixed for now
# 88     crashes when internet connection is lost even ...
# 89     i only hate the fact that the content images  ...
# 90     ill try to uninstall and reinstall  but it is ...
# 91                          learning app is stop working
# 92                            app videos is not working
# 93                              the app stops responding
# 94                       this app is rubbish not working
# 95                                             worst app
# 96                   theeeeeee worst app have ever faced
# 97                     this is worst app have ever used
# 98                 this app damage your wifi connections
# 99                            it not working  irritating
# 100                                    disappointing app
# 101                              it not good app so slow
# 102                              app is not working well
# 103                                   app is not working
# 104    this app deserve star this is very bad app  th...
# 105                            this app difficult to use
# 106                    worst app   it just keeps loading
# 107                       app is not working in my phone
# 108                                         so much bugs
# 109    overall experience is not good because it was ...
# 110                       not all features are available
# 111                                very slow and laggish
# 112                                 not working properly
# 113    not useful at all  don like this app as it shows
# 114                                         terrible app
# 115                 app buttons are not working properly
# 116                                    very terrible app
# 117                                      its not working
# 118                                        doesnot help
# 119                                              weird
# 120              why does the program not work properly
# 121                              app have so many issues
# 122    it is vey difficult for using it because it is...
# 123                                          terable app
# 124    it literally sucks   don install it cause it d...
# 125                                         very bad app
# 126                 really hate this app this is useless
# 127                                              garbage
# 128                                   slower application
# 129                                     it is abad app
# 130          keeps crashing on every device don know why
# 131      very bad disgusting app frnds donot install it
# 132                                         useless app
# 133                             app is freeze in between
# 134    completely garbage and useless at getting prob...
# 135                              scan option not working
# 136     need internet connection even for basic features
# 137    doesnot show solutions and hardly ever solve a...
# 138                                   completely useless
# 139                                            terrible
# 140                             application is troubling
# 141                                         terrible app
# 142                            app functions not working
# 143                                   its the worst app
# 144                   have not been able to download app
# 145        worst app  just waste of time app is crashing
# 146     very bad experience  it is totally useless app
# 147                                   nothing is working
# 148                                        a lot of bugs
# 149                                         very bad app
# 150      the app is very bad and is totally not usable
# 151                                    app does not work
# 152                                       worst app ever
# 153                                         doesnot work
# 154           worst app ever because this app canot show
# 155                                  it is the worst app
# 156                              this app is not working
# 157                                    not useful at all
# 158       this app is now really bad huge problem in app
# 159    very bad  always lies and says that it failed ...
# 160                            this thing is not working
# 161                                          useless app
# 162    my experience on this app has been very bad  h...
# 163                                      app is horrible
# 164                    hard to use and glitches so much
# 165    scanning doesnot work at all  such waste of ti...
# 166    used it handful of times and then it started c...
# 167             overall its good but it stacks sometimes
# 168                                        not working
# 169                            it was absolutely rubbish
# 170                             disgusting app ever used
# 171    after last update can not open apps and couldn...
# 172                                            worst app
# 173                                       worst app ever
# 174          i didnot find or get any help from this app
# 175                                      so many issues
# 176                                              bad app
# 177                                          not working
# 178                      i cant see any thing in the app
# 179                  good but some times connection down
# 180         some of the features not working in my phone
# 181                              apps options are freeze
# 182    not ready to use again because app have so man...
# 183             the app has freezing issue please fix it
# 184                                              its bad
# 185    boring app do not install not working in my phone
# 186                          stop sending notifications
# 187                      it honestly really annoying app
# 188    the app is decent but it cannot understand som...
# 189    i donot appreciate the lack of quality custome...
# 190                                       lots of errors
# 191              my comment cannot be sent to the people
# 192                                     its not updating
# 193    i did not understand that how to use this app ...
# 194    first they asked to sign up and then after sel...
# 195                                      it doesnot work
# 196    i can not receive the varification code so can...
# 197    doesnot let me sign in it says insufficient ro...
# 198                           waste of time it is so bad
# 199                            the app is not responding
# 200                                     so many spammers
# 201    i am giving this app stars because this app ha...
# 202                           full of bugs and glitches
# 203                            the app have so much bugs
# 204                                        full of bugs
# 205    data is so much exhausted think its bug in app...
# 206                              bug is so much annoying
# 207    also it counts every typo as mistake even if y...
# 208    again only available for most languages on the...
# 209                   app is not working in all language
# 210     the ios app has many features that they never...
# 211                              app is no sync properly
# 212                   desktop website has so many issues
# 213    this app would be best application in the worl...
# 214          app is not running same on different phones
# 215              desktop version is not working properly
# 216    updated review // updated  had hope    disappo...
# 217    i ve downloaded the latest update  restarted m...
# 218             app is not compatible with all langauges
# 219    when doing lesson that requires using the micr...
# 220       only use the on laptop impossible on the phone
# 221    i can use the app because its not running same...
# 222             app is not compatible with all platforms
# 223    recently switched to an android and am disappo...
# 224    the buttons donot even appear  ve left message...
# 225                 some issues can solve not compatible
# 226    the app really helpful but it has no langauge ...
# 227    i reset my phone and now it wont give the text...
# 228                          discussting app not running
# 229    why this app keep saying seem like there a con...
# 230    app have so many issue not working on website ...
# 231                                  please add galaries
# 232                              app is not so much good
# 233                    nice aap but there camera problem
# 234    i like this app but my problem is it keeps say...
# 235                                thres something wrong
# 236                              android app works bad
# 237    there is some kind of problem  tried with so m...
# 238     it takes too much time to load the website an...
# 239    add support for chromecast speed playback neve...
# 240                               website is not working
# 241         the udemy website is really trouble for me
# 242    feature is terrible  keeps hanging all the time
# 243    no connection error also popups even with most...
# 244    it is very annoying and will block them as am ...
# 245    it is great app  but even if have strong inter...
# 246    app was working fine until now  it has been cr...
# 247                               please add more option
# 248    make sure that the video fits the entire mobil...
# 249                               this app is very slow
# 250                              feature are not working
# 251                       phone features are not working
# 252    btw the website works fine but the mobile app ...
# 253                       new update to remove this bug
# 254                          some videos are not working
# 255    i can not watch my videos can please solve thi...
# 256                 play button doesn work  fix this one
# 257                                   the app is glitchy
# 258    please solve this issue  inbulit player doesn ...
# 259                            this app has really lack
# 260                       the progress bar shows so much
# 261                               please add search bar
# 262    this problem is frequent and it breaks the ent...
# 263                 but the app and website are horrible
# 264       spend lot of time for loading of the content
# 265                   te only problem is the downloading
# 266    i dont like this app this app have so much pr...
# 267                             horrible app not working
# 268        i can choose this app because its not working
# 269                      this app is not really good app
# 270              stupid app can even recognize may voice
# 271                                      i hate this app
# 272                         your app is stuck in between
# 273                                    worst application
# 274    waste of time the microphone doesn work at all...
# 275                              fix sync between device
# 276                                             not good
# 277                                         very bad app
# 278                                           both hard
# 279                                          not working
# 280                       extreme issue with erm device
# 281    it is trash not working same on different plat...
# 282                                          not working
# 283                     useless not working same on web
# 284                  app have not eligible on all system
# 285    none of the features appear on my android phon...
# 286                  i am very unsatisfied with this app
# 287                     it does not work in offline mode
# 288                            app should be more better
# 289      app is not work like on mobile app like web app
# 290              awful  the frame resizes automatically
# 291    very worst app experience  doesn work offline ...
# 292    doesnot work offline  slow as hell  doesnot in...
# 293                                       vioce problem
# 294    app is not working on same as phone definitely...
# 295                     keeps getting connection problem
# 296                  please set the voice access problem
# 297    i agree with all the comments complaining abou...
# 298    constantly does not register lesson completion...
# 299                        unbearable app is not working
# 300    the only good update was when they added darkm...
# 301                                        its worst now
# 302                             terrible and useless app
# 303                          app is not working properly
# 304                           remove hear system feature
# 305    remove the heart system if you still believe i...
# 306                 all feature are not working properly
# 307                               frequent facing issues
# 308                                 very disappointing
# 309                heart system features slow the system
# 310                         i am facing several problems
# 311    new heart system really sucks  the new heart s...
# 312              horrible  this app has changed so much
# 313                    please rise against heart feature
# 314    before the heart system would ve given this ap...
# 315                              the hearts system sucks
# 316                        can use the app very exasive
# 317                                 heart feature is bad
# 318    i used to love this app but its now pretty muc...
# 319    i have the paid version and the app doesn work...
# 320    starting was good  but the logic of heart is i...
# 321                               hear feature is not ok
# 322    but since they introduced the hearts system  d...
# 323    leaves permanent badge on the app so it always...
# 324                             app features is not good
# 325    the app proactively supports language but hear...
# 326    over time  more and more features have stopped...
# 327                                  application problem
# 328    what the hell is going on with the hearts and ...
# 329           i don like this app add some good features
# 330                 the heart system does not work well
# 331    can seem to refill the hearts using diamonds  ...
# 332    ditch the heart system and find better way to ...
# 333             have not been able to usemy app properly
# 334    the new hearts feature is so stupid and makes ...
# 335           i am sick of your stupid hearts features
# 336    the heart system does not work well with more ...
# 337    duolingo used to be great but the hearts updat...
# 338                             this heart feature worst
# 339    the newer hearts format is ridiculous  the new...
# 340    wish didn need to pay features not working smo...
# 341                      app have so many feature issues
# 342    why people are saying it a good app many featu...
# 343         after selecting some options its not working
# 344    if there is section of from grallery then it w...
# 345     so many problem  gallery feature must be include
# 346    i want one featured in these mind blowing app ...
# 347    i am disappointed with the app manay features ...
# 348    app is not better  some features are not worki...
# 349    app features are not good  must have gallery f...
# 350                        needs improvement in features
# 351                               add some more features
# 352                              remove useless features
# 353                  please put back the video ad option
# 354                                remove request option
# 355                          i am having feature issues
# 356                                     videos cant find
# 357    hi  discovered that many features of the websi...
# 358     worst app ve ever seen  features are not working
# 359       it soo expensive app and features are not good
# 360              this app can not even copy paste option
# 361    i dont like the app because options are not m...
# 362    app used to be way better years ago the animat...
# 363    there are errors in the features that make thi...
# 364              this app is terrible cant work app suck
# 365                                             not good
# 366                                          not working
# 367                            not good  app is crashing
# 368                              not open same as system
# 369                  these is not fast to get an answer
# 370    add some feature  think we can also upload photos
# 371                 it doesnot sync up with web version
# 372      kindly add the search feature as in desktop app
# 373                                      add more option
# 374                      i have problem while using app
# 375                    streaming is not working properly
# 376                                    features add more
# 377    maybe they could add more feature to cover mor...
# 378                                it doesnot open file
# 379                  need option to playback your voice
# 380    useless app in pronounce speak wrong but this ...
# 381    they dont know how to develop the app  they m...
# 382                           plz add some more features
# 383                 this app have not much good features
# 384    fix these issues and add auto capturing option...
# 385             notification option not working properly
# 386                       this app have so many features
# 387    send icon is hidden behind settings one  unusa...
# 388                            app have not many options
# 389    screen size problem and in drow mod is show do...
# 390                              scan option not working
# 391                             not able to use the scan
# 392                          scan feature is not working
# 393                               please add all cities
# 394         i thought it ok and was slowly learning some
# 395    working nicely for few days   but now not able...
# 396     app setting is app for disaster and poor rete...
# 397                      app is stuck not performed well
# 398    was great but app performance is not okay whic...
# 399    way too repetitive  you just keep doing the sa...
# 400    this is not free app you are limited by how ma...
# 401                                app is not running ok
# 402    they seemingly refuse to make it possible to d...
# 403    the camera does not work properly please fix t...
# 404    it is not good for study this app destroy student
# 405                                   worst never use it
# 406                  interface is not easy to understand
# 407                                     difficult to use
# 408                                     sign up problems
# 409    first time used and st time internal server er...
# 410                           so many issues in starting
# 411    sometimes the content does not load properly o...
# 412                                  i had some problems
# 413                           the problem still persists
# 414    very difficult to navigate to the content you ...
# 415          i am not able to add many some more courses
# 416                                    this is pathetic
# 417                           very disappointed  fix it
# 418                   a good app still can not download
# 419                    actually phone app is not working
# 420                                     lot of app issue
# 421            the content was good but not good enough
# 422                                terrible app slow app
# 423                   this app is unable to perform well
# 424    can scroll down when typing expression and it ...
# 425                                     it does not work
# 426    completely useless  just gets stuck in photo mode
# 427    apps not functioning waste of internet to down...
# 428                    now the send option isnot working
# 429    this aaap is very bad and never give right answer
# 430             it contains error to solve some problems
# 431                                         use less app
# 432                                       ridiculous app
# 433                                            worst app
# 434                                  really disappointed
# 435                      extremely slowly  not impressed
# 436                           doesn work properly at all
# 437     i am bored after using this app because its slow
# 438              poor  this app really needs improvement
# 439    unfortunately the implementation of the hearts...
# 440    i really enjoyed this in the past  today i ve ...
# 441                            app interface is not good
# 442    cant use the app duee to interface colors are ...
# 443                               app design is not good
# 444                         interface has so many issues
# 445        app is worst unable to understand where to go
# 446                 worst app all time id is not working
# 447    the app needs too much space in storage its re...
# 448                          user experience is not good
# 449                           the ui is unsable and slow
# 450                                        super bad ui
# 451             doesn work as well anymore  ui is broken
# 452                           the interface is cluttered
# 453                         interface is not good for me
# 454           everytime app upgrades  the app gets worse
# 455        the app was working well until recent update
# 456                           last update it is horrible
# 457                         frustrating to say the least
# 458    in the past  the app was helpful but after upd...
# 459    i used to love this app sooo much  used to spe...
# 460                   everything was good until updation
# 461     they ruined the app after updation shows many...
# 462                       latest update has some issues
# 463     the new upgrade seems to have caused problems  j
# 464    since the update  the lessons don open when cl...
# 465    each update seems to make it run slower and ad...
# 466    waste of time as you can not make mistakes  ma...
# 467    the screen becomes totally black after every u...
# 468    the app has issues related to content display ...
# 469    i lost all new update  tried to reinstall but ...
# 470                                need so many updation
# 471                                my app is not working
# 472         plz fix that by an update our something else
# 473        after last update videos not working properly
# 474                                     worst experience
# 475                             free version is rubbish
# 476                                          it not free
# 477                    it was fine before the new update
# 478            old version is best this version not best
# 479                  this app is so wack  after updation
# 480    after its last update this app got connection ...
# 481    i had really bad experience with this app  too...
# 482    i really dislike this app because its not working
# Name: User_Review, dtype: object
# <ipython-input-26-82b0d88f7623>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = summary.str.replace(r'^\$?([1-9]{1}[0-9]{0,2}(\,[0-9]{3})*(\.[0-9]{0,2})?|[1-9]{1}[0-9]{0,}(\.[0-9]{0,2})?|0(\.[0-9]{0,2})?|(\.[0-9]{1,2})?)$' , 'moneysymbol')
# <ipython-input-26-82b0d88f7623>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'(\d)' , '')
# <ipython-input-26-82b0d88f7623>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'^\D?(\d{3})\D?\D?(\d{3})\D?(\d{4})$' , ' ')
# <ipython-input-26-82b0d88f7623>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\s+' , ' ')
# <ipython-input-26-82b0d88f7623>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'[ \t]+$' , ' ')
# <ipython-input-26-82b0d88f7623>:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'[&#();*]' , ' ')
# <ipython-input-26-82b0d88f7623>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'[,:]' , ' ')
# <ipython-input-26-82b0d88f7623>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'[.!?\\-]' , ' ')
# <ipython-input-26-82b0d88f7623>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\'' , ' ')
# <ipython-input-26-82b0d88f7623>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\s[a-z]\s' , ' ')
# <ipython-input-26-82b0d88f7623>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\[[^\]]*\]',' ')
# <ipython-input-26-82b0d88f7623>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\"',' ')
# <ipython-input-26-82b0d88f7623>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   processed = processed.str.replace(r'\`',' ')

# %%
from nltk.corpus import stopwords

# %%
stopset = set(stopwords.words('english'))
vectorizer = TfidfVectorizer(use_idf=True, lowercase=True, strip_accents='ascii', stop_words=stopset)

# %%
stop_words = set(stopwords.words('english'))

# %%
processed = processed.apply(lambda x: ' ' .join(term for term in x.split() if term not in stop_words))

# %%
#print(processed)

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
processed = processed.apply(lambda x: ' ' .join(lemmatizer.lemmatize(term) for term in x.split()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e4dc7b88817f> in <module>
# ----> 1 processed = processed.apply(lambda x: ' ' .join(lemmatizer.lemmatize(term) for term in x.split()))
#
# ~\anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-21-e4dc7b88817f> in <lambda>(x)
# ----> 1 processed = processed.apply(lambda x: ' ' .join(lemmatizer.lemmatize(term) for term in x.split()))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
#processed

# %%
from nltk.tokenize import word_tokenize #bag of words approach

# %%
allwords = []
for message in processed:
    words = word_tokenize(message)
    for w in words:
        allwords.append(w)
        
allwords = nltk.FreqDist(allwords)

print('Number of words: {}'.format(len(allwords)))
print('most common words: {}'.format(allwords.most_common(50)))
# Out:
# Number of words: 722
# most common words: [('app', 244), ('working', 66), ('feature', 53), ('problem', 33), ('good', 33), ('many', 33), ('work', 32), ('heart', 31), ('time', 28), ('much', 26), ('add', 25), ('update', 24), ('issue', 24), ('properly', 24), ('ad', 22), ('worst', 22), ('bad', 21), ('like', 19), ('use', 19), ('really', 18), ('system', 18), ('please', 17), ('fix', 16), ('option', 16), ('connection', 15), ('useless', 14), ('get', 14), ('phone', 14), ('used', 12), ('annoying', 12), ('need', 12), ('lesson', 12), ('doesnot', 12), ('version', 11), ('video', 11), ('able', 11), ('internet', 11), ('slow', 10), ('show', 10), ('even', 10), ('bug', 10), ('fine', 9), ('well', 9), ('website', 9), ('make', 9), ('new', 9), ('crashing', 8), ('free', 8), ('remove', 8), ('say', 8)]

# %%
word_features = allwords.most_common(50)
word_features = [i[0] for i in word_features]
print(word_features)
# Out:
# ['app', 'working', 'feature', 'problem', 'good', 'many', 'work', 'heart', 'time', 'much', 'add', 'update', 'issue', 'properly', 'ad', 'worst', 'bad', 'like', 'use', 'really', 'system', 'please', 'fix', 'option', 'connection', 'useless', 'get', 'phone', 'used', 'annoying', 'need', 'lesson', 'doesnot', 'version', 'video', 'able', 'internet', 'slow', 'show', 'even', 'bug', 'fine', 'well', 'website', 'make', 'new', 'crashing', 'free', 'remove', 'say']

# %%
def find_features(message):
    words = word_tokenize(message)
    features = {}
    for word in word_features:
        features[word] = (word in words)
    return features

features = find_features(processed[0])

for key, value in features.items():
    if value == True:
        print(key)
# Out:
# app
# crashing

# %%
processed[0]
# Out:
# 'app crashing'

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(processed).toarray()

# %%
y = df.Review_Type

# %%
y
# Out:
# 0      AppCrash
# 1      AppCrash
# 2      AppCrash
# 3      AppCrash
# 4            PI
# 5      AppCrash
# 6      AppCrash
# 7            PI
# 8      AppCrash
# 9            FI
# 10           PI
# 11     AppCrash
# 12     AppCrash
# 13     AppCrash
# 14     AppCrash
# 15           AI
# 16           AI
# 17           AI
# 18           AI
# 19           AI
# 20           AI
# 21           AI
# 22           AI
# 23           AI
# 24           AI
# 25           AI
# 26           AI
# 27           AI
# 28           AI
# 29           AI
# 30           AI
# 31           AI
# 32           AI
# 33           AI
# 34           AI
# 35           AI
# 36           AI
# 37           AI
# 38           AI
# 39           AI
# 40           AI
# 41           AI
# 42           AI
# 43           AI
# 44           AI
# 45           AI
# 46           AI
# 47     AppCrash
# 48     AppCrash
# 49     AppCrash
# 50     AppCrash
# 51     AppCrash
# 52     AppCrash
# 53     AppCrash
# 54     AppCrash
# 55     AppCrash
# 56     AppCrash
# 57     AppCrash
# 58     AppCrash
# 59     AppCrash
# 60     AppCrash
# 61     AppCrash
# 62     AppCrash
# 63     AppCrash
# 64     AppCrash
# 65     AppCrash
# 66     AppCrash
# 67     AppCrash
# 68     AppCrash
# 69     AppCrash
# 70     AppCrash
# 71     AppCrash
# 72     AppCrash
# 73     AppCrash
# 74     AppCrash
# 75     AppCrash
# 76     AppCrash
# 77     AppCrash
# 78     AppCrash
# 79     AppCrash
# 80     AppCrash
# 81     AppCrash
# 82     AppCrash
# 83     AppCrash
# 84     AppCrash
# 85     AppCrash
# 86     AppCrash
# 87     AppCrash
# 88     AppCrash
# 89     AppCrash
# 90     AppCrash
# 91     AppCrash
# 92     AppCrash
# 93     AppCrash
# 94     AppCrash
# 95     AppCrash
# 96     AppCrash
# 97     AppCrash
# 98     AppCrash
# 99     AppCrash
# 100    AppCrash
# 101    AppCrash
# 102    AppCrash
# 103    AppCrash
# 104    AppCrash
# 105    AppCrash
# 106    AppCrash
# 107    AppCrash
# 108    AppCrash
# 109    AppCrash
# 110    AppCrash
# 111    AppCrash
# 112    AppCrash
# 113    AppCrash
# 114    AppCrash
# 115    AppCrash
# 116    AppCrash
# 117    AppCrash
# 118    AppCrash
# 119    AppCrash
# 120    AppCrash
# 121    AppCrash
# 122    AppCrash
# 123    AppCrash
# 124    AppCrash
# 125    AppCrash
# 126    AppCrash
# 127    AppCrash
# 128    AppCrash
# 129    AppCrash
# 130    AppCrash
# 131    AppCrash
# 132    AppCrash
# 133    AppCrash
# 134    AppCrash
# 135    AppCrash
# 136    AppCrash
# 137    AppCrash
# 138    AppCrash
# 139    AppCrash
# 140    AppCrash
# 141    AppCrash
# 142    AppCrash
# 143    AppCrash
# 144    AppCrash
# 145    AppCrash
# 146    AppCrash
# 147    AppCrash
# 148    AppCrash
# 149    AppCrash
# 150    AppCrash
# 151    AppCrash
# 152    AppCrash
# 153    AppCrash
# 154    AppCrash
# 155    AppCrash
# 156    AppCrash
# 157    AppCrash
# 158    AppCrash
# 159    AppCrash
# 160    AppCrash
# 161    AppCrash
# 162    AppCrash
# 163    AppCrash
# 164    AppCrash
# 165    AppCrash
# 166    AppCrash
# 167    AppCrash
# 168    AppCrash
# 169    AppCrash
# 170    AppCrash
# 171    AppCrash
# 172    AppCrash
# 173    AppCrash
# 174    AppCrash
# 175    AppCrash
# 176    AppCrash
# 177    AppCrash
# 178    AppCrash
# 179    AppCrash
# 180    AppCrash
# 181    AppCrash
# 182    AppCrash
# 183    AppCrash
# 184    AppCrash
# 185    AppCrash
# 186          BR
# 187          BR
# 188          BR
# 189          BR
# 190          BR
# 191          BR
# 192          BR
# 193          BR
# 194          BR
# 195          BR
# 196          BR
# 197          BR
# 198          BR
# 199          BR
# 200          BR
# 201          BR
# 202          BR
# 203          BR
# 204          BR
# 205          BR
# 206          BR
# 207          CI
# 208          CI
# 209          CI
# 210          CI
# 211          CI
# 212          CI
# 213          CI
# 214          CI
# 215          CI
# 216          CI
# 217          CI
# 218          CI
# 219          CI
# 220          CI
# 221          CI
# 222          CI
# 223          CI
# 224          CI
# 225          CI
# 226          CI
# 227          CI
# 228          CI
# 229          CI
# 230          CI
# 231          CI
# 232          CI
# 233          CI
# 234          CI
# 235          CI
# 236          CI
# 237          CI
# 238          CI
# 239          CI
# 240          CI
# 241          CI
# 242          CI
# 243          CI
# 244          CI
# 245          CI
# 246          CI
# 247          CI
# 248          CI
# 249          CI
# 250          CI
# 251          CI
# 252          CI
# 253          CI
# 254          CI
# 255          CI
# 256          CI
# 257          CI
# 258          CI
# 259          CI
# 260          CI
# 261          CI
# 262          CI
# 263          CI
# 264          CI
# 265          CI
# 266          CI
# 267          CI
# 268          CI
# 269          CI
# 270          CI
# 271          CI
# 272          CI
# 273          CI
# 274          CI
# 275          CI
# 276          CI
# 277          CI
# 278          CI
# 279          CI
# 280          CI
# 281          CI
# 282          CI
# 283          CI
# 284          CI
# 285          CI
# 286          CI
# 287          CI
# 288          CI
# 289          CI
# 290          CI
# 291          CI
# 292          CI
# 293          CI
# 294          CI
# 295          CI
# 296          CI
# 297          FI
# 298          FI
# 299          FI
# 300          FI
# 301          FI
# 302          FI
# 303          FI
# 304          FI
# 305          FI
# 306          FI
# 307          FI
# 308          FI
# 309          FI
# 310          FI
# 311          FI
# 312          FI
# 313          FI
# 314          FI
# 315          FI
# 316          FI
# 317          FI
# 318          FI
# 319          FI
# 320          FI
# 321          FI
# 322          FI
# 323          FI
# 324          FI
# 325          FI
# 326          FI
# 327          FI
# 328          FI
# 329          FI
# 330          FI
# 331          FI
# 332          FI
# 333          FI
# 334          FI
# 335          FI
# 336          FI
# 337          FI
# 338          FI
# 339          FI
# 340          FI
# 341          FI
# 342          FI
# 343          FI
# 344          FI
# 345          FI
# 346          FI
# 347          FI
# 348          FI
# 349          FI
# 350          FI
# 351          FI
# 352          FI
# 353          FI
# 354          FI
# 355          FI
# 356          FI
# 357          FI
# 358          FI
# 359          FI
# 360          FI
# 361          FI
# 362          FR
# 363          FR
# 364          FR
# 365          FR
# 366          FR
# 367          FR
# 368          FR
# 369          FR
# 370          FR
# 371          FR
# 372          FR
# 373          FR
# 374          FR
# 375          FR
# 376          FR
# 377          FR
# 378          FR
# 379          FR
# 380          FR
# 381          FR
# 382          FR
# 383          FR
# 384          FR
# 385          FR
# 386          FR
# 387          FR
# 388          FR
# 389          FR
# 390          FR
# 391          FR
# 392          FR
# 393          FR
# 394          PI
# 395          PI
# 396          PI
# 397          PI
# 398          PI
# 399          PI
# 400          PI
# 401          PI
# 402          PI
# 403          PI
# 404          PI
# 405          PI
# 406          PI
# 407          PI
# 408          PI
# 409          PI
# 410          PI
# 411          PI
# 412          PI
# 413          PI
# 414          PI
# 415          PI
# 416          PI
# 417          PI
# 418          PI
# 419          PI
# 420          PI
# 421          PI
# 422          PI
# 423          PI
# 424          PI
# 425          PI
# 426          PI
# 427          PI
# 428          PI
# 429          PI
# 430          PI
# 431          PI
# 432          PI
# 433          PI
# 434          PI
# 435          PI
# 436          PI
# 437          PI
# 438          PI
# 439          UI
# 440          UI
# 441          UI
# 442          UI
# 443          UI
# 444          UI
# 445          UI
# 446          UI
# 447          UI
# 448          UI
# 449          UI
# 450          UI
# 451          UI
# 452          UI
# 453          UI
# 454          VU
# 455          VU
# 456          VU
# 457          VU
# 458          VU
# 459          VU
# 460          VU
# 461          VU
# 462          VU
# 463          VU
# 464          VU
# 465          VU
# 466          VU
# 467          VU
# 468          VU
# 469          VU
# 470          VU
# 471          VU
# 472          VU
# 473          VU
# 474          VU
# 475          VU
# 476          VU
# 477          VU
# 478          VU
# 479          VU
# 480          VU
# 481          VU
# 482         NaN
# Name: Review_Type, dtype: object

# %%
print (X.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-58ee8b2b2c73> in <module>
# ----> 1 print (X.shape)
#
# NameError: name 'X' is not defined

# %%
print (y.shape)
# Out:
# (483,)

# %%
#pd.DataFrame(X, columns=vectorizer.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
clf = naive_bayes.MultinomialNB()
clf.fit(X_train, y_train)
clf.predict(X_test)
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-2264469b142c> in <module>()
#       1 clf = naive_bayes.MultinomialNB()
# ----> 2 clf.fit(X_train, y_train)
#       3 clf.predict(X_test)
#       4 y_pred = clf.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     587
#     588         labelbin = LabelBinarizer()
# --> 589         Y = labelbin.fit_transform(y)
#     590         self.classes_ = labelbin.classes_
#     591         if Y.shape[1] == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     434             Shape will be [n_samples, 1] for binary problems.
#     435         """
# --> 436         return self.fit(y).transform(y)
#     437
#     438     def transform(self, y):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit(self, y)
#     403         self : returns an instance of self.
#     404         """
# --> 405         self.y_type_ = type_of_target(y)
#     406         if 'multioutput' in self.y_type_:
#     407             raise ValueError("Multioutput target data is not supported with "
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     279         aux = ar[perm]
#     280     else:
# --> 281         ar.sort()
#     282         aux = ar
#     283     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.26804123711340205

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
logreg = LogisticRegression(solver='liblinear', random_state=0)
#fit the model
logreg.fit(X_train, y_train)
y_pred_test = logreg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-5cfc2ca2241b> in <module>()
#       3 logreg = LogisticRegression(solver='liblinear', random_state=0)
#       4 #fit the model
# ----> 5 logreg.fit(X_train, y_train)
#       6 y_pred_test = logreg.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1284         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1285                          accept_large_sparse=solver != 'liblinear')
# -> 1286         check_classification_targets(y)
#    1287         self.classes_ = np.unique(y)
#    1288         n_samples, n_features = X.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     166     y : array-like
#     167     """
# --> 168     y_type = type_of_target(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     170                       'multilabel-indicator', 'multilabel-sequences']:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     279         aux = ar[perm]
#     280     else:
# --> 281         ar.sort()
#     282         aux = ar
#     283     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.26804123711340205

# %%
from sklearn import svm
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-bf33e3aeca78> in <module>()
#       4
#       5 #Train the model using the training sets
# ----> 6 clf.fit(X_train, y_train)
#       7
#       8 #Predict the response for test dataset
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     148                          order='C', accept_sparse='csr',
#     149                          accept_large_sparse=False)
# --> 150         y = self._validate_targets(y)
#     151
#     152         sample_weight = np.asarray([]
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in _validate_targets(self, y)
#     517     def _validate_targets(self, y):
#     518         y_ = column_or_1d(y, warn=True)
# --> 519         check_classification_targets(y)
#     520         cls, y = np.unique(y_, return_inverse=True)
#     521         self.class_weight_ = compute_class_weight(self.class_weight, cls, y_)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     166     y : array-like
#     167     """
# --> 168     y_type = type_of_target(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     170                       'multilabel-indicator', 'multilabel-sequences']:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     285         return 'continuous' + suffix
#     286
# --> 287     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     288         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     289     else:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     279         aux = ar[perm]
#     280     else:
# --> 281         ar.sort()
#     282         aux = ar
#     283     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.26804123711340205

# %%
#RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Create the model with 100 trees
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
# Fit on training data
model.fit(X_train, y_train)
rf_predictions = model.predict(X_test)
#testing set accuracy
print("Accuracy:",metrics.accuracy_score(y_test, rf_predictions))
print(classification_report(y_test, rf_predictions))
# Out:
# Accuracy: 0.8469656992084432
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.79      0.82       104
#      Neutral       0.50      0.03      0.06        34
#     Positive       0.85      0.99      0.91       241
#
#    micro avg       0.85      0.85      0.85       379
#    macro avg       0.73      0.60      0.60       379
# weighted avg       0.82      0.85      0.81       379
